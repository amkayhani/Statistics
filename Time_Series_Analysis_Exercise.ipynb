# %% [markdown]
# <a href="https://colab.research.google.com/github/amkayhani/Statistics/blob/main/Time_Series_Analysis_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock Price Time Series Analysis Exercise
#
# In this exercise, you will explore and analyze a dataset containing historical stock prices. You'll apply time series analysis techniques to understand trends, seasonal patterns, and forecast future stock prices.
#
# **Instructions**:
# 1. Choose a stock (e.g., Apple, Google, Microsoft) and obtain its historical price data. You can use the loaded data fetched from the Yahoo Finance.
# 2. Load the data into a DataFrame. The data should include columns like Date, Open, Close, High, Low, and Volume.
# 3. Convert the Date column to a DateTime type and set it as the DataFrame index.
# 4. Conduct exploratory data analysis to find the descriptive statistics and understand the dataset. Plot the closing price over time. (this step has been done partially)
# 5. Conduct the time series analysis to identify its trend and seasonal components.
# 6. Forecast future stock prices and visualize the results.
#
# **Note**: Make sure to install necessary libraries like `pandas`, `matplotlib`, `statsmodels`, or `yfinance` if you want to run this code localy in your own laptop or computer. (not in Google Colab)

# %%
# Import necessary libraries
import yfinance as yf
import matplotlib.pyplot as plt

# Fetch historical stock prices for Apple
ticker_symbol = 'AAPL'
stock_data = yf.download(ticker_symbol, start='2012-01-01', end='2022-01-01')

# Display the first few rows of the fetched data
print(stock_data.head())

# Visualize the closing prices
plt.figure(figsize=(12, 6))
plt.plot(stock_data['Close'], label=f'Closing Prices of {ticker_symbol}')
plt.title(f'Historical Stock Prices of {ticker_symbol}')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2012-01-03  14.621429  14.732143  14.607143  14.686786  12.449690  302220800
# 2012-01-04  14.642857  14.810000  14.617143  14.765714  12.516599  260022000
# 2012-01-05  14.819643  14.948214  14.738214  14.929643  12.655556  271269600
# 2012-01-06  14.991786  15.098214  14.972143  15.085714  12.787856  318292800
# 2012-01-09  15.196429  15.276786  15.048214  15.061786  12.767572  394024400
